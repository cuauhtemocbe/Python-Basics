# %% [markdown]
# <a href="https://colab.research.google.com/github/cuauhtemocbe/Python-Basics/blob/main/2.%20Operadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operadores <br>
# Los operadores son usados para realizar **operaciones** en variables y valores. <br><br>
# Se dividen en:
# 1. **Básicos**
# *   Aritméticos: + , - , * , / , **
# *   Asignación: =
# *   Comparación: ==, !=, >, >=, <=
#
# 2. **Avanzados**
# *   Lógicos: and, or, not
# *   Identidad: is, is not

# %% [markdown]
# # 1.1 Operadores aritméticos
# <br>
# Para hacer operaciones matématicas básicas en variables, valores númericos y algunos con texto (cadenas de caracteres => string)

# %%
#@title Tabla operadores aritméticos { run: "auto", vertical-output: true }
import pandas as pd
pd.DataFrame(columns=['Operador', 'Nombre', 'Ejemplo'],
             index=[1, 2, 3, 4, 5, 6, 7],
             data=[['+', 'Adición', 'x + y   ,   "texto" + " otro texto"'],
                   ['-', 'Sustracción', 'x - y'], 
                   ['*', 'Multiplicación', 'x * y   ,   "texto" * 4'],
                   ['/', 'División', 'x / y'],
                   ['//', 'Cociente', 'x // y'], 
                   ['%', 'Módulo', 'x % y'],
                   ['**', 'Potenciación', 'x ** y']])

# %% [markdown]
# ## Adición

# %%
# Adición
print(7 + 5)

# %%
# Recuerda que también podemos hacer operaciones con VARIABLES
x, y = 7, 5
print(x + y)

# %%
# Adición con string
palabra = 'Zen de '
palabra_2 = "Python"
print(palabra + palabra_2)

# %% [markdown]
# ## Sustracción

# %%
# Sustración
print(x - y)

# %% [markdown]
# ## Multiplicación

# %%
# Multiplicación
print(x * y)

# %%
# Multiplicación con string
print(palabra_2 * 10)

# %% [markdown]
#  ## División

# %%
# División
x, y = 7, 5
print(x / y)
print(type(x / y))

# %% [markdown]
# ## Módulo
# Nos permite obtene el **resto** ó **residuo** de una división entera. <br>
#
# Por ejemplo 7 **MOD** 5 devolverá 2, ya que al realizar la división entera de 7 entre 5 se obtiene 1 como cociente y 2 como residuo. <br>

# %% [markdown]
# ![Modulo_v2.png](data:image/png;base64,...)

# %%
print(7 % 5)

# %% [markdown]
# Si tenemos 19 **MOD** 4 devolverá 3, ya que al realizar la división entera de 19 entre 4 se obtiene 4 como cociente y 3 como resto.

# %%
print(19 % 4)

# %% [markdown]
# **Número par:** <br>
# Si un número es múltiplo de 2 es par. <br>
# Si el **residuo** de **mod 2** es igual a 0, nuestro número será par.

# %%
print(2 % 2)

# %% [markdown]
# **Número impar:** <br>
# Si un número es NO es múltiplo de 2 es impar. <br>
# Si el **residuo** de **mod 2** es diferente a 0, nuestro número será impar.

# %%
print(3 % 2)

# %% [markdown]
# ## Potenciación

# %%
a = 2
print(a ** 3) # 2 * 2 * 2

# %%
print(a ** 4) # 2 * 2 * 2 * 2

# %%
print(a ** 1)

# %%
print(a ** 0)

# %% [markdown]
# ## Orden de evaluación
#
# Al igual que en matematicas, al evaluarse una operación, se debe considerar la prioridad de las operaciones.

# %%
print(10 + 2 / 2)

# %%
print((10 + 2) / 2)

# %% [markdown]
# # 1.2 Operadores de asignaciones

# %%
#@title Tabla operadores de asignación
import pandas as pd
pd.DataFrame(columns=['Operador', 'Nombre', 'Ejemplo'],
             index=[1, 2, 3, 4, 5, 6, 7],
             data=[['=', 'igual a', 'mi_variable = 150'],
                   ['+=', 'más igual a', 'x = x + 4'], 
                   ['-=', 'menos igual a', 'x = x - 4'],
                   ['*=', 'multipliación igual a', 'x = x * 4'],
                   ['/=', 'división igual a', 'x = x / 4'], 
                   ['%=', 'módulo igual a', 'x %= y'],
                   ['**=', 'exponenciación igual a', 'x **= y']])

# %% [markdown]
# ## Operador = <br>
# Asigna a la variable (izquierda) un valor (derecha).
#
# x = 1

# %%
x = 1
print(x)

# %% [markdown]
# ## Operador +=
# El operador += suma y asigna a la variable (izquierda) la adición de la variable con el el valor (derecha).

# %% [markdown]
# Esto es:

# %%
x = 6
x = x + 4
print(x)

# %% [markdown]
# es igual a:

# %%
x = 6
x += 4
print(x)

# %% [markdown]
# Tendrá más sentido si revisas las dos opciones en la siguiente celda. ¿Qué opción te gusta más?

# %%
# Ejemplo
contador = 1
for n in range(10):
  print(contador)
  contador = contador + 1 # Opción 1
  # contador += 1 # Opción 2
  
# Recuerda comentar una de las dos opciones para ejecutar el código.

# %% [markdown]
# Este operador también puede ser usado con cadenas de caracteres (string)

# %%
texto = 'Hola'
texto = texto + '_' # 'Hola' + '_'
texto = texto + 'Mundo' # 'Hola_' + 'Mundo'
print(texto)
print(type(texto))

# %%
texto = 'Hola'
texto += '_'  # 'Hola' + '_'
texto += 'Mundo' # 'Hola_' + 'Mundo'
print(texto)
print(type(texto))

# %% [markdown]
# ## Operador   **-=**
# El operador -= resta y asigna a la variable (izquierda) el valor (derecha).

# %%
x = 6
x = x - 4
print(x)

# %%
x = 6
x -= 4
print(x)

# %%
x = 6
x =- 4
print(x)

# %% [markdown]
# ## Operador ***=** <br>
# El operador *= multiplica y asigna a la variable (izquierda) el valor (derecha).

# %%
x = 6
x = x * 4
print(x)

# %%
x = 6
x *= 4 
print(x)

# %% [markdown]
# ## Operador /=
# El operador /= divide y asigna a la variable (izquierda) el valor (derecha).

# %%
x = 6
x = x / 4
print(x)

# %%
x = 6
x /= 4
print(x)

# %% [markdown]
# # 1.3 Operadores de comparación <br>
# * Son usados para comparar dos valores
# *   Al usar estos operadores obtendremos un boleano: True, False
# *   Si la comparación es *verdadera* regresa **True** y **False** si es falsa.

# %%
#@title Tabla operadores de comparación { run: "auto", vertical-output: true }
import pandas as pd
pd.DataFrame(columns=['Operador', 'Nombre', 'Ejemplo'],
             index=[1, 2, 3, 4, 5, 6],
             data=[['==', 'Igual que', 'x == y'],
                   ['!=', 'No es igual que', 'x != y'], 
                   ['>', 'Mayor que', 'x > y'],
                   ['>=', 'Mayor o igual que', 'x >= y'],
                   ['<', 'Menor que', 'x < y'],
                   ['<=', 'Menor o igual que', 'x <= y']])

# %% [markdown]
# ## Operador **==**

# %% [markdown]
# En el siguiente ejemplo, estamos comparando si el valor 1 es igual que el valor 1. <br>Sabemos 1 es igual a 1, por ello el resultado es True

# %%
print(1 == 1)
print(type(1 == 1))

# %% [markdown]
# **Recuerda que** al utilizar operadores de comparación nos devolveran un valor de tipo **boleano**

# %% [markdown]
# Revisa el siguiente ejemplo. Cuál crees que será el resultado: True o False

# %%
print(1 == 2)
print(type(1 == 2))

# %% [markdown]
# Al ser falsa la afirmación, arroja un False.

# %%
a, b, c = 2, 3, 3
# 2 == 3
print(a == b)

# %%
# 3 == 3
print(b == c)

# %%
# 3 == 2
print(c == a)

# %%
resultado = c == a
print(resultado)

# %% [markdown]
# El operador igual que también es usado con cadenas de caracteres:

# %%
print('atún' == 'Atún')
print(type('atún' == 'Atún'))

# %% [markdown]
# Ya que las dos palabras no son iguales, arrojara un False

# %%
print('atún' == 'atún')
print(type('atún' == 'atún'))

# %%
print('atún'.lower() == 'Atún'.lower())

# %% [markdown]
# ## Operador **!=**

# %%
a, b, c = 2, 3, 3

# %%
# 2 != 3
print(a != b)

# %%
# 3 != 3
print(b != c)

# %%
# 3 != 2
print(c != a)

# %% [markdown]
# El operador no es igual que también es usado con cadenas de caracteres:

# %%
'atún' != 'Atún'

# %% [markdown]
# Ambas palabras son diferentes, lo que cumple la condición de "no es igual que"

# %%
'atún' != 'atún'

# %% [markdown]
# Y al ser iguales, ya no se cumple la condición "no es igual que"

# %% [markdown]
# ## Operador **>**

# %%
a, b, c = 2, 3, 3

# %%
# 2 > 3
print(a > b)

# %%
# 3 > 3
print(b > c)

# %%
# 3 > 2
print(c > a)

# %% [markdown]
# ## Operador **>=**

# %%
a, b, c = 2, 3, 3

# %%
# 2 >= 3
print(a >= b)

# %%
# 3 >= 3
print(b >= c)

# %%
# 3 >= 2
print(c >= a)

# %% [markdown]
# ## Operador **<**

# %%
a, b, c = 2, 3, 3

# %%
# 2 < 3
print(a < b)

# %%
# 3 < 3
print(b < c)

# %%
# 3 < 2
print(c < a)

# %% [markdown]
# ## Operador **<=**

# %%
a, b, c = 2, 3, 3

# %%
# 2 <= 3
print(a <= b)

# %%
# 3 <= 3
print(b <= c)

# %%
# 3 <= 2
print(c <= a)

# %% [markdown]
# # 2. Ejercicios

# %% [markdown]
# ## Aritméticos
# Realiza las siguiente operaciones aritméticas:
#
# **Ejemplo:** Múltiplica **11** con **13**, e imprime el resultado
#
# `>>> print(11 * 13)` <br>
# `143`

# %% [markdown]
# 1. Múltiplica **8** por **4** por **10**, e imprime el resultado. Resultado esperado: 320

# %% [markdown]
# 2. Suma **20** más **3** y resta **50**, e imprime el resultado. Resultado esperado: -27

# %% [markdown]
# 3. Divide **10** entre el resultado de **1** más **3**. Resultado esperado 2.5

# %% [markdown]
# 4. Obtenen el resultado de 15 mod 3, e imprime el resultado. Resultado esperado: 0

# %% [markdown]
# 5. Obtenen el resultado de 150 mod 16, e imprime el resultado. Resultado esperado: 6

# %% [markdown]
# ## Comparación
# Realiza las siguientes operaciones de comparación <br>
#
# Ej. Asigna el valor 15 a la variable "valor_moneda"<br>
# ```
# valor_moneda = 15
# ```

# %% [markdown]
# 1. a) Asigna el valor 10 a la variable `"diez"` <br>
# b) Asigna el valor 20 a la variable `"veinte"`
# c) Usa el operador `mayor igual que`, e imprime el resultado. Resultado esperado: False

# %% [markdown]
# 2. Convierte a código la siquiente expresión: <br>
# `20` `menor que`  `"20.0001"` <br>
# **Notas:** <br>
# 20 es de tipo int <br>
# "20.0001" es de tipo str <br>
# Usa el casteo (casting) <br>
# Resultado esperado: True

# %% [markdown]
# 3. a) Asigna el valor 12 a la variable `"valor_original"` <br>
# b) Asigna el valor 12 a la variable `"valor_modificado"` <br>
# c) Compara ambos resultados con el operador **igual que**, e imprime el resultado. Resultado esperado: True

# %% [markdown]
# 4. Compara si el texto 1 es **igual que** el texto 2, e imprime el resultado. Resultado esperado: False

# %%
texto_1 = 'Marty! Tienes que venir conmigo, de regreso al futuro!'
texto_2 = 'Marty! Tienes que venir conmigo, de regreso a1 futuro!'

# %% [markdown]
# 5. Compara si la frase 1 es **diferente que** la frase 2, e imprime el resultado. Resultado esperado: True

# %%
frase_1 = 'Marty, lo siento, pero la única fuente de poder capaz de generar 1.21 giga watts de potencia eléctrica es un rayo'
frase_2 = 'Marty, lo siento, pero la única fuente de poder capaz de generar 1.21 giga watts de potencia e1éctrica es un rayo'

# %% [markdown]
# ![back_to_the_past.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # 1.4 Operadores Lógicos
#
# Nos ayudan a aevaluar múltiples condiciones.
#
# **Palabras clave:** `and`, `or` y `not`

# %%
#@title Tabla operadores de lógicos { run: "auto", vertical-output: true }
import pandas as pd
from IPython.display import display, HTML

def pretty_print(df):
    return display(HTML(df.to_html().replace("\\n","<br>") ) )

df = pd.DataFrame(columns=['Operador', 'Descripcción', 'Ejemplo'],
             index=[1, 2, 3],
             data=[['and', 'True si ambas evaluaciones son True', 'True and True == a True \\n True and False == False'],
                   ['or', 'True si alguna evaluación es True', 'True or True == False \n True or False == True'], 
                   ['not', 'False si alguna evaluación es False', 'True or False == False, \n False or False']])

pretty_print(df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Operador</th>
#       <th>Descripcción</th>
#       <th>Ejemplo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>and</td>
#       <td>True si ambas evaluaciones son True</td>
#       <td>True and True == a True <br> True and False == False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>or</td>
#       <td>True si alguna evaluación es True</td>
#       <td>True or True == False <br> True or False == True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>not</td>
#       <td>False si alguna evaluación es False</td>
#       <td>True or False == False, <br> False or False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## and

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %% [markdown]
# ## or

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# ## not

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# **Fuentes:** <br>
# https://www.w3schools.com/python/python_operators.asp
# <br>
# https://entrenamiento-python-basico.readthedocs.io/es/latest/leccion3/operadores_asignaciones.html
# <br>
# https://es.khanacademy.org/computing/computer-science/cryptography/modarithmetic/a/what-is-modular-arithmetic
