# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/Python\ Basics/1.Python\ basics\ -\ Introducción.ipynb ./

# %%
# !jupyter nbconvert --to html "1.Python_basics.ipynb"
# Out:
# [NbConvertApp] Converting notebook 1.Python_basics.ipynb to html
# [NbConvertApp] Writing 286807 bytes to 1.Python_basics.html

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
print('Buenos días')
# Out:
# Buenos días

# %%
print(10*'Hello, World!')
# Out:
# Hello, World!Hello, World!Hello, World!Hello, World!Hello, World!Hello, World!Hello, World!Hello, World!Hello, World!Hello, World!

# %%
print(10*'Hello, World! \n')
# Out:
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!

# %%
print(world)
# Out:
# world

# %%
helloworld = hello + " " + world
print(helloworld)
# Out:
# hello world

# %%
type(helloworld)
# Out:
# str

# %%
a, b, d = 2, 3, 5
c = a + b + d
print(c)
# Out:
# 10

# %%
one = 1
print(type(one))
one_str = str(1)
print(type(one_str))
# Out:
# <class 'int'>
# <class 'str'>

# %%
one_str
# Out:
# '1'

# %%
one = int('1')
type(one)
# Out:
# int

# %%
# This will not work!
one = '1'
two = str(2)
hello = "hello"

print(one + two + hello)
# Out:
# 12hello

# %%
radius = int(input("Enter the radius:"))
# Out:
# Enter the radius:30

# %%
area = round((radius * radius) * 3.1415, 2)

# %%
print("The area of a circle with radius",radius,"is:",area)
# Out:
# The area of a circle with radius 30 is: 2827.35

# %%
def print_welcome_text(name):
    print(f'{name} , te doy la bienvenida a este curso. Espero que aprendaas'
          'muucho y te inicie en la zenda del programador')
